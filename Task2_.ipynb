# %% [markdown]
# # Task 2 — Predicting Customer Holiday Purchases (Executed)
# This notebook runs on a synthetic dataset; replace the CSV with your data to reproduce on real data.

# %% [markdown]
# ## Sample data (first 5 rows)

# %%
import pandas as pd
pd.read_csv('Customer_Booking_synthetic.csv').head()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LeadTimeDays</th>
#       <th>Age</th>
#       <th>PastHolidayPurchases</th>
#       <th>LoyaltyTier</th>
#       <th>IncomeBand</th>
#       <th>DestinationType</th>
#       <th>TripType</th>
#       <th>BookingOrigin</th>
#       <th>BookedHoliday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>28</td>
#       <td>40</td>
#       <td>1</td>
#       <td>Bronze</td>
#       <td>Mid</td>
#       <td>Short-haul</td>
#       <td>Business</td>
#       <td>Web</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34</td>
#       <td>69</td>
#       <td>1</td>
#       <td>Silver</td>
#       <td>Low</td>
#       <td>Short-haul</td>
#       <td>Leisure</td>
#       <td>Web</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>23</td>
#       <td>47</td>
#       <td>0</td>
# ...

# %% [markdown]
# ## Model evaluation metrics

# %%
print('Metrics below')
# Out:
# Accuracy: 0.717
# Precision: 0.581
# Recall: 0.272
# F1: 0.370
# ROC AUC: 0.651

# %% [markdown]
# ## Confusion Matrix (test set)

# %%
import numpy as np
cm = np.array([[190, 18], [67, 25]])
cm
# Out:
# [[190, 18], [67, 25]]

# %% [markdown]
# ## Classification report

# %%
print('Classification report below')
# Out:
#               precision    recall  f1-score   support
#
#            0      0.739     0.913     0.817       208
#            1      0.581     0.272     0.370        92
#
#     accuracy                          0.717       300
#    macro avg      0.660     0.593     0.594       300
# weighted avg      0.691     0.717     0.680       300

# %% [markdown]
# ## Top feature importances

# %%
import pandas as pd
pd.DataFrame()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>feature</th>
#       <th>importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Age</td>
#       <td>0.278036</td>
#     </tr>
#     <tr>
#       <td>LeadTimeDays</td>
#       <td>0.240607</td>
#     </tr>
#     <tr>
#       <td>PastHolidayPurchases</td>
#       <td>0.131874</td>
#     </tr>
#     <tr>
#       <td>LoyaltyTier</td>
#       <td>0.092629</td>
#     </tr>
#     <tr>
#       <td>BookingOrigin_Mobile</td>
#       <td>0.027948</td>
#     </tr>
#     <tr>
#       <td>IncomeBand_Low</td>
#       <td>0.025205</td>
#     </tr>
#     <tr>
#       <td>DestinationType_Short-haul</td>
#       <td>0.025178</td>
#     </tr>
#     <tr>
#       <td>BookingOrigin_Web</td>
#       <td>0.024592</td>
#     </tr>
#     <tr>
#       <td>DestinationType_Long-haul</td>
#       <td>0.024340</td>
#     </tr>
#     <tr>
#       <td>BookingOrigin_Agent</td>
# ...

# %% [markdown]
# ## Saved artifacts
# - Model: /mnt/data/rf_pipeline_task2_synthetic.joblib
# - Test predictions: /mnt/data/task2_test_predictions_synthetic.csv
# - Synthetic CSV: /mnt/data/Customer_Booking_synthetic.csv
